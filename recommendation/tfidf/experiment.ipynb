# %%
import pickle
import pandas as pd

# %%
import os
path=r"C:\tensor_code\kluebot\data\raw\2017_1.csv"
path.split('\\')[-1][:-4]
# Out:
# '2017_1.'

# %%
data=pd.read_csv('C:/tensor_code/kluebot/Recommendation_System/recommendation/tfidf/lecture_vector.csv',index_col=False)

# %%
vectors=data[data.columns[2:]]

# %%
with open('./lec_vec_2017_1','rb') as f:
    haha=pickle.load(f)

# %%
from sklearn.decomposition import PCA

data=pd.DataFrame(haha).T
pca = PCA(n_components=2)
y = pca.fit_transform(data)

data['pca_x']=y[:,0]
data['pca_y']=y[:,1]

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
from matplotlib import font_manager,rc

font_path = "C:/Windows/Fonts/HMFMPYUN.TTF"
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font',family=font_name)

plt.figure(figsize=(10,10))
for i,an in enumerate(data.index.values):

    x = data['pca_x'].iloc[i]
    y = data['pca_y'].iloc[i]
    plt.scatter(x, y, marker='x', color='blue')
    if (i+5)%50==0:
        plt.text(x+0.01, y+0.01, an, fontsize=10,color='black')
        
plt.show()
